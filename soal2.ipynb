# %%
import matplotlib.pyplot as plt
import statistics
import pandas as pd
import numpy as np
from scipy import stats

# %%
s2_a = 0
s2_b = 1
s2_c = 4
s2_d = 7 
s2_e = 5
s2_f = 0
hasil_a = s2_a + s2_b + s2_c + s2_d + s2_e + s2_f
print("======soal 1 ========")
print("maka hasil dari s2 adalah : " + str(hasil_a))
s1_a = 4
s1_b = 12
s1_c = 6
s1_d = 13
s1_e = 14
s1_f = 0
hasil_b = s1_a + s1_b + s1_c + s1_d + s1_e + s1_f
print("maka hasil dari s1 adalah : " + str(hasil_b)) 
sma_a = 12
sma_b = 17
sma_c = 5
sma_d = 20 
sma_e = 11
sma_f = 75
hasil_c = sma_a + sma_b + sma_c + sma_d + sma_e + sma_f
print("maka hasil dari SMA adalah : " + str(hasil_c))
smp_a = 5 
smp_b = 6
smp_c = 15
smp_d = 9
smp_e = 20
smp_f = 15
hasil_d = smp_a + smp_b + smp_c + smp_d + smp_e + smp_f
print("maka hasil dari SMP adalah : " + str(hasil_d))
sd_a = 1
sd_b = 8
sd_c = 0
sd_d = 19
sd_e = 10
sd_f = 1
hasil_e = sd_a + sd_b + sd_c + sd_d + sd_e + sd_a
print("maka hasil dari SD adalah : " + str(hasil_e))
td_a = 2
td_b = 14
td_c = 3
td_d = 10
td_e = 0
td_f = 1
hasil_f = td_a + td_b + td_c + td_d + td_e + td_f
print("maka hasil dari TIDAK DIKETAHUI adalah : " + str(hasil_f))
print()
print("======soal 2======")
hasil1 = hasil_a * 0.25
hasil2 = hasil_b * 0.20
hasil3 = hasil_c * 0.15
hasil4 = hasil_d * 0.10
hasil5 = hasil_e * 0.05
hasil6 = hasil_f * 0.03
print("maka hasil dari S2 adalah : " + str(hasil1))
print("maka hasil dari S1 adalah : " + str(hasil2))
print("maka hasil dari SMA adalah : " + str(hasil3))
print("maka hasil dari SMP adalah : " + str(hasil4))
print("maka hasil dari SD adalah : " + str(hasil5))
print("maka hasil dari TIDAK DIKETAHUI adalah : " + str(hasil6))
print()
print("====soal 3====")
a_index = 0.25
b_index = 0.20
c_index = 0.15
d_index = 0.10
e_index = 0.05
f_index = 0.03
s2 = 0 * a_index
s1 = 4 * b_index
sma = 12 * c_index
smp = 5 * d_index
sd = 1 * e_index
td = 2 * f_index

s2_1 = 1 * a_index
s1_1 = 12 * b_index
sma_1 = 17 * c_index
smp_1 = 6 * d_index
sd_1 = 8 * e_index
td_1 = 14 * f_index

s2_2 = 4 * a_index
s1_2 = 6 * b_index
sma_2 = 5 * c_index
smp_2 = 15 * d_index
sd_2 = 0 * e_index
td_2 = 3 * f_index

s2_3 = 7 * a_index
s1_3 = 13 * b_index
sma_3 = 20 * c_index
smp_3 = 9 * d_index
sd_3 = 19 * e_index
td_3 = 10 * f_index

s2_4 = 5 * a_index
s1_4 = 14 * b_index
sma_4 = 11 * c_index
smp_4 = 20 * d_index
sd_4 = 10 * e_index
td_4 = 0 * f_index

s2_5 = 0 * a_index
s1_5 = 0 * b_index
sma_5 = 75 * c_index
smp_5 = 15 * d_index
sd_5 = 1 * e_index
td_5 = 1 * f_index

print("usia 70")
print("maka hasil bobot dari S2 adalah : " + str(s2))
print("maka hasil bobot dari S1 adalah : " + str(s1))
print("maka hasil bobot dari SMA adalah : " + str(sma))
print("maka hasil bobot dari SMP adalah : " + str(smp))
print("maka hasil bobot dari SD adalah : " + str(sd))
print("maka hasil bobot dari TIDAK DIKETAHUI adalah : " + str(td))
print("usia 60")
print("maka hasil bobot dari S2 adalah : " + str(s2_1))
print("maka hasil bobot dari S1 adalah : " + str(s1_1))
print("maka hasil bobot dari SMA adalah : " + str(sma_1))
print("maka hasil bobot dari SMP adalah : " + str(smp_1))
print("maka hasil bobot dari SD adalah : " + str(sd_1))
print("maka hasil bobot dari TIDAK DIKETAHUI adalah : " + str(td_1))
print("usia 50")
print("maka hasil bobot dari S2 adalah : " + str(s2_2))
print("maka hasil bobot dari S1 adalah : " + str(s1_2))
print("maka hasil bobot dari SMA adalah : " + str(sma_2))
print("maka hasil bobot dari SMP adalah : " + str(smp_2))
print("maka hasil bobot dari SD adalah : " + str(sd_2))
print("maka hasil bobot dari TIDAK DIKETAHUI adalah : " + str(td_2))
print("usia 40")
print("maka hasil bobot dari S2 adalah : " + str(s2_3))
print("maka hasil bobot dari S1 adalah : " + str(s1_3))
print("maka hasil bobot dari SMA adalah : " + str(sma_3))
print("maka hasil bobot dari SMP adalah : " + str(smp_3))
print("maka hasil bobot dari SD adalah : " + str(sd_3))
print("maka hasil bobot dari TIDAK DIKETAHUI adalah : " + str(td_3))
print("usia 30")
print("maka hasil bobot dari S2 adalah : " + str(s2_4))
print("maka hasil bobot dari S1 adalah : " + str(s1_4))
print("maka hasil bobot dari SMA adalah : " + str(sma_4))
print("maka hasil bobot dari SMP adalah : " + str(smp_4))
print("maka hasil bobot dari SD adalah : " + str(sd_4))
print("maka hasil bobot dari TIDAK DIKETAHUI adalah : " + str(td_4))
print("usia 20")
print("maka hasil bobot dari S2 adalah : " + str(s2_5))
print("maka hasil bobot dari S1 adalah : " + str(s1_5))
print("maka hasil bobot dari SMA adalah : " + str(sma_5))
print("maka hasil bobot dari SMP adalah : " + str(smp_5))
print("maka hasil bobot dari SD adalah : " + str(sd_5))
print("maka hasil bobot dari TIDAK DIKETAHUI adalah : " + str(td_5))
print()
print("====soal 4====")
terkecil = {"usia 70 : 24"}
print("maka bobot terkecil adalah : " + str(terkecil))
print()
print("====soal 5====")

fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
pendidikan = ['S2', 'S1', 'SMA', 'SMP', 'SD', 'Tidak Diketahui']
jumlah = [17, 49, 140, 70, 39, 30]
c = ['pink', 'blue', 'purple'] 
plt.title("jumlah berdasarkan jumlah orang")
plt.bar(pendidikan, jumlah, color = c)
plt.show()
print()
#pie chart 
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
plt.title("jumlah berdasarkan jumlah orang")
pendidikan = ['S2', 'S1', 'SMA', 'SMP', 'SD', 'Tidak Diketahui']
jumlah = [17, 49, 140, 70, 39, 30]
ax.pie(jumlah,labels=pendidikan,autopct='%1.2f%%')
plt.show()
print()
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
pendidikan = ['u70', 'u60', 'u50', 'u40', 'u30', 'u20']
jumlah = [24, 58, 33, 78, 60, 92]
c = ['pink', 'blue', 'purple'] 
plt.title("jumlah berdasarkan usia")
plt.bar(pendidikan, jumlah, color = c)
plt.show()
print()
#pie chart 
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
plt.title("jumlah berdaasarkan usia")
pendidikan = ['u70', 'u60', 'u50', 'u40', 'u30', 'u20']
jumlah = [24, 58, 33, 78, 60, 92]
ax.pie(jumlah,labels=pendidikan,autopct='%1.2f%%')
plt.show()
print()
# Out:
# ======soal 1 ========
# maka hasil dari s2 adalah : 17
# maka hasil dari s1 adalah : 49
# maka hasil dari SMA adalah : 140
# maka hasil dari SMP adalah : 70
# maka hasil dari SD adalah : 39
# maka hasil dari TIDAK DIKETAHUI adalah : 30
#
# ======soal 2======
# maka hasil dari S2 adalah : 4.25
# maka hasil dari S1 adalah : 9.8
# maka hasil dari SMA adalah : 21.0
# maka hasil dari SMP adalah : 7.0
# maka hasil dari SD adalah : 1.9500000000000002
# maka hasil dari TIDAK DIKETAHUI adalah : 0.8999999999999999
#
# ====soal 3====
# usia 70
# maka hasil bobot dari S2 adalah : 0.0
# maka hasil bobot dari S1 adalah : 0.8
# maka hasil bobot dari SMA adalah : 1.7999999999999998
# maka hasil bobot dari SMP adalah : 0.5
# maka hasil bobot dari SD adalah : 0.05
# maka hasil bobot dari TIDAK DIKETAHUI adalah : 0.06
# usia 60
# maka hasil bobot dari S2 adalah : 0.25
# maka hasil bobot dari S1 adalah : 2.4000000000000004
# maka hasil bobot dari SMA adalah : 2.55
# ...
