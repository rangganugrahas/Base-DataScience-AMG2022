# %%
import statistics
import pandas as pd
import numpy as np
from scipy import stats

# %%
beras = 11400 #perkg
minyak = 12700 #perliter
ayam = 3400  #peepr100gram
telur = 21800    #per 1 kg
popok = 27000    #per pcs
sabun_cuci = 1800   #per 100 gram
buah_anggur = 3800   #per 100 gram
roti_tawar = 8500   #per 100 gram
tissu =6400    #per pcs
mie_instan = 2200  #per pcs
diskon = 90
diskon1 = 85
diskon2 = 80
diskon3 = 75

print("belanjaan tia")
beras_tia = 4
ayam_tia = 2
telur_tia = 3
sabun_tia = 5
buah_anggur_tia = 4
roti_tia = 2
mie_tia = 12
jb_tia= (beras_tia * beras) + (ayam_tia * (ayam * 10)) + (telur_tia * telur) + (sabun_tia * sabun_cuci) + (buah_anggur_tia * buah_anggur) + (roti_tia * roti_tawar) + (mie_tia * mie_instan)
jb_diskon_tia = (jb_tia/100) * diskon1
print("maka jumlah belanja tia adalah " + str(jb_tia) + " rupiah")
print("maka jumlah belanja tia setelah mendapatkan diskon adalah " + str(jb_diskon_tia))
print()
print("belanjaan hana")
minyak_hana = 2
ayam_hana = 5
telur_hana = 1.5
sabun_hana = 3
anggur_hana = 8
roti_hana = 3
tisu_hana = 2
mie_hana = 20
jb_hana = (minyak_hana * minyak) + (ayam_hana * ayam) + (telur_hana * telur) + (sabun_hana * sabun_cuci) + (anggur_hana * buah_anggur) + (roti_hana * roti_tawar) +(tisu_hana * tissu) + (mie_hana * mie_instan)
jb_diskon_hana = (jb_hana/100) * diskon 
print("maka jumlah belanjaan hana adalah " + str(jb_hana) + " rupiah")
print("maka jumlah belanjaan hana setelah mendapat diskonn adalah " + str(jb_diskon_hana))
print()
print("belanjaan widia")
beras_widia = 1
minyak_widia = 1
telur_widia = 1
anggur_widia = 5
tissu_widia = 3
mie_widia = 16
jb_widia = (beras_widia * beras) + (minyak_widia * minyak) + (telur_widia * telur) + (anggur_widia * buah_anggur) + (tissu_widia * tissu) + (mie_widia * mie_instan)
print("maka jumlah belanjaan widia adalah " + str(jb_widia) + " rupiah")
print()


print("belanjaan romi")
minyak_romi = 3
telur_romi = 2
popok_romi = 4
sabun_romi = 8
mie_romi = 8
jb_romi = (minyak_romi * minyak) + (telur_romi * telur) + (popok_romi * popok) + (sabun_romi * sabun_cuci) + (mie_romi * mie_instan)
jb_diskon_romi = (jb_romi/100) * diskon1 
print("maka jumlah belanjaan romi adalah " + str(jb_romi) + " rupiah")
print("maka jumlah belanjaan romi setelah mendapat diskonn adalah " + str(jb_diskon_romi))
print()
print("belanjaan samsul")
ayam_samsul = 3
telur_samsul = 4
popok_samsul = 2
anggur_samsul = 7
tissu_samsul = 5
mie_samsul = 10
jb_samsul =(ayam_samsul * (ayam * 10)) + (telur_samsul * telur) + (popok_samsul * popok) + (anggur_samsul * buah_anggur) + (tissu_samsul * tissu) + (mie_samsul * mie_instan)
jb_diskon_samsul = (jb_samsul/100) * diskon3 
print("maka jumlah belanjaan samsul adalah " + str(jb_samsul) + " rupiah")
print("maka jumlah belanjaan samsul setelah mendapat diskonn adalah " + str(jb_diskon_samsul))
print()

print("belanjaan dimas")
ayam_dimas = 5
popok_dimas = 5
sabun_dimas = 4
anggur_dimas = 3
roti_dimas = 5
mie_dimas =6
jb_dimas = (ayam_dimas *(ayam * 10)) + (popok_dimas * popok) + (sabun_dimas * sabun_cuci) + (anggur_dimas * buah_anggur) + (roti_dimas * roti_tawar) + (mie_dimas * mie_instan)
jb_diskon_dimas = (jb_dimas/100) * diskon3
print("maka jumlah belanjaan dimas adalah " + str(jb_dimas) + " rupiah")
print("maka jumlah belanjaan dimas setelah mendapat diskonn adalah " + str(jb_diskon_dimas))
print()

print("maka jumlah belanja tia adalah " + str(jb_diskon_tia))
print("maka jumlah belanja hana  adalah " + str(jb_diskon_hana))
print("maka jumlah belanja widia  adalah " + str(jb_widia))
print("maka jumlah belanja romi  adalah " + str(jb_diskon_romi))
print("maka jumlah belanja samsul  adalah " + str(jb_diskon_samsul))
print("maka jumlah belanja samsul  adalah " + str(jb_diskon_dimas))

print("==soal 3==")
maxz = [284475]
print("maka jumlah belanjaan paling besar setelah diskon adalah dimas rp. " + str(maxz))
print("==soal 4===")
terpersen = {"hana" : "rp. 173880"}
print("maka yang mendapatkan diskon 10 persen adalah : " + str(terpersen))
# Out:
# belanjaan tia
# maka jumlah belanja tia adalah 246600 rupiah
# maka jumlah belanja tia setelah mendapatkan diskon adalah 209610.0
#
# belanjaan hana
# maka jumlah belanjaan hana adalah 193200.0 rupiah
# maka jumlah belanjaan hana setelah mendapat diskonn adalah 173880.0
#
# belanjaan widia
# maka jumlah belanjaan widia adalah 119300 rupiah
#
# belanjaan romi
# maka jumlah belanjaan romi adalah 221700 rupiah
# maka jumlah belanjaan romi setelah mendapat diskonn adalah 188445.0
#
# belanjaan samsul
# maka jumlah belanjaan samsul adalah 323800 rupiah
# maka jumlah belanjaan samsul setelah mendapat diskonn adalah 242850.0
#
# belanjaan dimas
# maka jumlah belanjaan dimas adalah 379300 rupiah
# maka jumlah belanjaan dimas setelah mendapat diskonn adalah 284475.0
#
# maka jumlah belanja tia adalah 209610.0
# maka jumlah belanja hana  adalah 173880.0
# maka jumlah belanja widia  adalah 119300
# maka jumlah belanja romi  adalah 188445.0
# maka jumlah belanja samsul  adalah 242850.0
# ...
