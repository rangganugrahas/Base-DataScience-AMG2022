# %%
import matplotlib.pyplot as plt
import statistics
import pandas as pd
import numpy as np
from scipy import stats

# %%
print("======Soal 1=======")
print()
laba1 = 32500000
laba2 = 31000000
laba3 = 42000000
laba4 = 51500000
laba5 = 27000000
asset1 = 0.08
asset2 = 0.04
asset3 = 0.12
asset4 = 0.11
asset5 = 0.03
xis = 20
log = 14
cin = 28
namic = 42
psilon =18
jml_a = ((xis * 300000) + (xis * 75000))
print("Pengeluaran Gaji karyawan + asuransi di perusahaan A-xis : " +str(jml_a))
jml_b = ((log * 360000) + (log * 75000))
print("Pengeluaran Gaji karyawan + asuransi di perusahaan B-Log : " +str(jml_b))
jml_c = ((cin * 475000) + (cin * 75000))
print("Pengeluaran Gaji karyawan + asuransi di perusahaan C-in : " +str(jml_c))
jml_d = ((namic * 580000) + (namic * 75000))
print("Pengeluaran Gaji karyawan + asuransi di perusahaan D-Namic : " +str(jml_d))
jml_e = ((psilon * 400000) + (psilon * 75000))
print("Pengeluaran Gaji karyawan + asuransi di perusahaan E-psilon : " +str(jml_e))
print()
print("======soal 2=======")
pajak = 0.03
pertahun = 12
jml_1 = (laba1 * pajak) + (asset1 * 280000000)
print("total pajak pertahun : " + str(jml_1))
jml_2 = (laba2 * pajak) + (asset2 * 310000000)
print("total pajak pertahun : " + str(jml_2))
jml_3 = (laba3 * pajak) + (asset3 * 420000000)
print("total pajak pertahun : " + str(jml_3))
jml_4 = (laba4 * pajak) + (asset4 * 550000000)
print("total pajak pertahun : " + str(jml_4))
jml_5 = (laba5 * pajak) + (asset5 * 340000000)
print("total pajak pertahun : " + str(jml_5))


fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
indeks = ['A-Xis', 'B-Log', 'C-In', 'D-Namic', 'E-psilon']
jumlah =[23375000.0, 13330000.0, 51660000.0, 62045000.0, 11010000.0]
c = ['green', 'red', 'yellow', 'purple', 'grey']
plt.title("Data Pengeluaran Pajak dan Gaji")
plt.xlabel("perusahaan")
plt.ylabel("nilai")
plt.bar(indeks, jumlah, color = c)
plt.grid(True)
plt.show


import matplotlib.pyplot as plt
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
plt.title("Data pengeluaran pajak dan gaji")
nama = ['A-Xis', 'B-Log', 'C-In', 'D-Namic', 'E-Psilon']
jml = [23375000.0, 13330000.0, 51660000.0, 62045000.0, 11010000.0]
ax.pie(jml,labels=nama,autopct='%1.2f%%')
plt.show()



print("======soal 3=======")
asset_a = 280000000
asset_b = 310000000
asset_c = 420000000
asset_d = 550000000
asset_e = 340000000
csr = 0.025
csr2 = 0.035
hasil_1 =  asset_a * csr
print("maka csr perusahaan a adalah : " + str(hasil_1)) 
hasil_2 =  asset_b * csr2
print("maka csr perusahaan b adalah : " + str(hasil_2)) 
hasil_3 =  asset_c * csr2
print("maka csr perusahaan c adalah : " + str(hasil_3)) 
hasil_4 =  asset_d * csr2
print("maka csr perusahaan d adalah : " + str(hasil_4)) 
hasil_5 =  asset_e * csr2
print("maka csr perusahaan e adalah : " + str(hasil_5)) 


import matplotlib.pyplot as plt
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
plt.title("Data pengeluaran pajak dan gaji")
nama = ['A-Xis', 'B-Log', 'C-In', 'D-Namic', 'E-Psilon']
jml = [700000000.0, 1085000000.0, 1470000000.0, 1925000000.0,  1190000000.0]
ax.pie(jml,labels=nama,autopct='%1.2f%%')
plt.show()


print("======soal 4=======")
hasil1 = laba1 * 12
print("total laba satu tahun di perusahaan A-xis : " + str(hasil1)) 
hasil2 = laba2 * 12
print("total laba satu tahun di perusahaan B-Log : " + str(hasil2))
hasil3 = laba3 * 12
print("total laba satu tahun di perusahaan C-in : " + str(hasil3))
hasil4 = laba4 * 12
print("total laba satu tahun di perusahaan D-namic : " + str(hasil4))
hasil5 = laba5 * 12
print("total laba satu tahun di perusahaan E-psilon : " + str(hasil5))
hasil6 = hasil1 + hasil2 + hasil3 + hasil4 + hasil5
print("hasil semua laba selama satu tahun adalah : " + str(hasil6))
print()
print("========soal 5 =======")
hasil_a = (laba1 * 12 ) - csr * 280000000 - (7500000 * 12 ) - 23375000.0
print("total pendapatan bersih pertahun perusahaan a : " + str(hasil_a))
hasil_b = (laba2 * 12 ) - csr2 * 310000000 - (6090000 * 12 ) - 13330000.0
print("total pendapatan bersih pertahun perusahaan b : " + str(hasil_b))
hasil_c = (laba3 * 12 ) - csr2 * 420000000 - ( 15400000 * 12 ) -  51660000.0
print("total pendapatan bersih pertahun perusahaan c : " + str(hasil_c))
hasil_d = (laba4 * 12 ) - csr2 * 550000000 - (27510000 * 12 ) - 62045000.0
print("total pendapatan bersih pertahun perusahaan d : " + str(hasil_d))
hasil_e = (laba5 * 12 ) - csr2 * 340000000 - (8550000 * 12 ) - 11010000.0
print("total pendapatan bersih pertahun perusahaan e : " + str(hasil_e))
print()
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
indeks = ['A-Xis', 'B-Log', 'C-In', 'D-Namic', 'E-psilon']
jumlah =[ 269625000.0, 274740000.0, 252840000.0, 206585000.0,  198490000.0]
c = ['green', 'red', 'yellow', 'purple', 'grey']
plt.title("Data Pendapatan bersih pertahun")
plt.xlabel("perusahaan")
plt.ylabel("nilai")
plt.bar(indeks, jumlah, color = c)
plt.grid(True)
plt.show
print()
import matplotlib.pyplot as plt
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
plt.title("Data pendapatan bersih pertahun")
nama = ['A-Xis', 'B-Log', 'C-In', 'D-Namic', 'E-Psilon']
jml = [ 269625000.0, 274740000.0, 252840000.0, 206585000.0,  198490000.0]
ax.pie(jml,labels=nama,autopct='%1.2f%%')
plt.show()
# Out:
# ======Soal 1=======
#
# Pengeluaran Gaji karyawan + asuransi di perusahaan A-xis : 7500000
# Pengeluaran Gaji karyawan + asuransi di perusahaan B-Log : 6090000
# Pengeluaran Gaji karyawan + asuransi di perusahaan C-in : 15400000
# Pengeluaran Gaji karyawan + asuransi di perusahaan D-Namic : 27510000
# Pengeluaran Gaji karyawan + asuransi di perusahaan E-psilon : 8550000
#
# ======soal 2=======
# total pajak pertahun : 23375000.0
# total pajak pertahun : 13330000.0
# total pajak pertahun : 51660000.0
# total pajak pertahun : 62045000.0
# total pajak pertahun : 11010000.0
# ======soal 3=======
# maka csr perusahaan a adalah : 7000000.0
# maka csr perusahaan b adalah : 10850000.000000002
# maka csr perusahaan c adalah : 14700000.000000002
# maka csr perusahaan d adalah : 19250000.0
# maka csr perusahaan e adalah : 11900000.000000002
# ======soal 4=======
# total laba satu tahun di perusahaan A-xis : 390000000
# total laba satu tahun di perusahaan B-Log : 372000000
# ...
