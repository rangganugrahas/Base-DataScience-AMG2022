# %%
import matplotlib.pyplot as plt
import statistics
import pandas as pd
import numpy as np
from scipy import stats

# %%
print("======Soal 1=======")
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
pendidikan = ['Paskibra', 'PMR', 'Pramuka', 'Futsal', 'volly', 'Kesenian', 'Rohis']
jumlah = [5, 18, 30, 7, 16, 19, 12]
c = ['pink', 'blue', 'purple'] 
plt.title("jumlah siswa yang mengikuti ekstrakulikuler di kelas 10")
plt.bar(pendidikan, jumlah, color = c)
plt.show()
print("=====Soal 2=======")
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
pendidikan = ['Paskibra', 'PMR', 'Pramuka', 'Futsal', 'volly', 'Kesenian', 'Rohis']
jumlah = [32, 34, 62, 51, 38, 41, 29]
c = ['pink', 'blue', 'purple'] 
plt.title("jumlah siswa yang mengikuti disetiap eskulnya")
plt.bar(pendidikan, jumlah, color = c)
plt.show()
print("=======soal 3========")

fut_a = 7
fut_b = 29
fut_c = 15
vol_a = 16
vol_b = 10
vol_c = 12
m = 287 
tm = 45
hasilfut = fut_a + fut_b + fut_c + vol_a + vol_b + vol_c
print("maka yang ikut eskul olahraga adalah : " + str(hasilfut))
hasilnya = m - hasilfut
print("maka nilai baru dari yang mengikuti eskul adalah : " + str(hasilnya))
print("yang tidak mengikuti eskul adalah : " + str(tm))
hasilf1 = (tm / 332) * 100
hasilf2 = (hasilfut / 332)* 100
hasilf3 = (hasilnya / 332)* 100
print("yang tidak mengikuti eskul adalah : " +str(hasilf1))
print("yang mengikuti eskul olahraga  adalah : " +str(hasilf2))
print("yang mengikuti semua eskul adalah : " +str(hasilf3))

print()
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
pendidikan = ['olahraga', 'tidak mengikuti', 'Mengikuti']
jumlah = [13.55, 26.80, 59.63]
c = ['pink', 'blue', 'purple'] 
plt.title("hasil persentase bar")
plt.bar(pendidikan, jumlah, color = c)
plt.show()
print()
#pie chart 
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
plt.title("jumlah persentase pie chart")
pendidikan = ['olahraga', 'tidak mengikuti', 'Mengikuti']
jumlah = [13.55, 26.80, 59.63]
ax.pie(jumlah,labels=pendidikan,autopct='%1.2f%%')
plt.show()

print("=======soal 4========")
k10 = 17
k11 = 8
k12 = 20
index = 45

hasil10 = (k10 / index)*100
hasil11 = (k11 / index)*100
hasil12 = (k12 / index)*100
print("maka jumlah yang tidak mengikuti eskul di tingkatan 10 adalah : " + str(hasil10))
print("maka jumlah yang tidak mengikuti eskul di tingkatan 11 adalah : " + str(hasil11))
print("maka jumlah yang tidak mengikuti eskul di tingkatan 12 adalah : " + str(hasil12))
#pie chart 
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
plt.title("jumlah siswa yang tidak mengikuti eskul")
pendidikan = ['Kelas 10', 'Kelas 11', 'Kelas 12']
jumlah = [3.7, 1.7, 4.4]
ax.pie(jumlah,labels=pendidikan,autopct='%1.2f%%')
plt.show()


print("=======soal 5========")
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
pendidikan = ['Paskibra', 'PMR', 'Pramuka', 'Futsal', 'volly', 'Kesenian', 'Rohis']
jumlah = [5, 18, 30, 7, 16, 19, 12]
c = ['pink', 'blue', 'purple'] 
plt.title("jumlah siswa yang mengikuti ekstrakulikuler di kelas 10")
plt.bar(pendidikan, jumlah, color = c)
plt.show()
print()
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
pendidikan = ['Paskibra', 'PMR', 'Pramuka', 'Futsal', 'volly', 'Kesenian', 'Rohis']
jumlah = [21, 4, 8, 29, 10, 18, 10]
c = ['pink', 'blue', 'purple'] 
plt.title("jumlah siswa yang mengikuti ekstrakulikuler di kelas 11")
plt.bar(pendidikan, jumlah, color = c)
plt.show()
print()
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
pendidikan = ['Paskibra', 'PMR', 'Pramuka', 'Futsal', 'volly', 'Kesenian', 'Rohis']
jumlah = [6, 12, 24, 15, 12, 4, 7]
c = ['pink', 'blue', 'purple'] 
plt.title("jumlah siswa yang mengikuti ekstrakulikuler di kelas 12")
plt.bar(pendidikan, jumlah, color = c)
plt.show()
print()
#pie chart 
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
plt.title("jumlah siswa yang mengikuti ekstrakulikuler di kelas 10")
pendidikan = ['Paskibra', 'PMR', 'Pramuka', 'Futsal', 'volly', 'Kesenian', 'Rohis']
jumlah = [5, 18, 30, 7, 16, 19, 12]
ax.pie(jumlah,labels=pendidikan,autopct='%1.2f%%')
plt.show()
print()
#pie chart 
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
plt.title("jumlah siswa yang mengikuti ekstrakulikuler di kelas 11")
pendidikan = ['Paskibra', 'PMR', 'Pramuka', 'Futsal', 'volly', 'Kesenian', 'Rohis']
jumlah = [21, 4, 8, 29, 10, 18, 10]
ax.pie(jumlah,labels=pendidikan,autopct='%1.2f%%')
plt.show()
print()
#pie chart 
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
plt.title("jumlah siswa yang mengikuti ekstrakulikuler di kelas 12")
pendidikan = ['Paskibra', 'PMR', 'Pramuka', 'Futsal', 'volly', 'Kesenian', 'Rohis']
jumlah = [6, 12, 24, 15, 12, 4, 7]
ax.pie(jumlah,labels=pendidikan,autopct='%1.2f%%')
plt.show()
# Out:
# ======Soal 1=======
# =====Soal 2=======
# =======soal 3========
# maka yang ikut eskul olahraga adalah : 89
# maka nilai baru dari yang mengikuti eskul adalah : 198
# yang tidak mengikuti eskul adalah : 45
# yang tidak mengikuti eskul adalah : 13.55421686746988
# yang mengikuti eskul olahraga  adalah : 26.80722891566265
# yang mengikuti semua eskul adalah : 59.63855421686747
# =======soal 4========
# maka jumlah yang tidak mengikuti eskul di tingkatan 10 adalah : 37.77777777777778
# maka jumlah yang tidak mengikuti eskul di tingkatan 11 adalah : 17.77777777777778
# maka jumlah yang tidak mengikuti eskul di tingkatan 12 adalah : 44.44444444444444
# =======soal 5========
