# %%
import matplotlib.pyplot as plt
import statistics
import pandas as pd
import numpy as np
from scipy import stats

# %%
burger = 24000
pizza =52000
dimsum =30000
ekkado = 7500
milkshake = 10000
es_krim =15000

print("======soal 1========")
burger1 = 6
pizza1 = 3
dimsum1= 4
ekkado1 = 4
milkshake1 = 2
es1 = 5
js = (burger1 * burger) + (pizza1 * pizza) + (dimsum1 * dimsum) + (ekkado1 * ekkado) + (milkshake1 * milkshake) + (es1 * es_krim)
jb = burger1 + pizza1 + dimsum1 + ekkado1 + milkshake1 + es1
print("maka jumlah semua makanan yang dipesan adalah : " + str(js))
print("jumlah semua belanjaan : " + str(jb))
print()
print("======soal 2=======")
f1 = burger1 / jb
f2 = pizza1 / jb
f3 = dimsum1 / jb
f4 = ekkado1 / jb
f5 = milkshake1 / jb
f6 = es1 / jb
print("Burger : " + str(f1))
print("Pizza : " + str(f2))
print("Dimsum : " + str(f3))
print("Ekkado : " + str(f4))
print("Milkshake : " + str(f5))
print("Eskrim : " + str(f6))


import matplotlib.pyplot as plt
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
plt.title("Jumlah pesanan setelah dipresentaseukan")
nama = ['burger', 'pizza', 'dimsum', 'ekkado', 'milkshake', 'eskrim']
jml = [0.25, 0.125, 0.16666666666666666, 0.16666666666666666, 0.08333333333333333, 0.20833333333333334]
ax.pie(jml,labels=nama,autopct='%1.2f%%')
plt.show()

print()
print("=====Soal 3=====")
print("=====Ahmad=====")
ba = 4
pa = 2
j1 = 7.5

jml_a = (0.70 * ((ba * burger) + (pa * pizza))) + (j1 * 2000) - 5000
print("maka jumlah belanja amad : " + str(jml_a))
kem_a = 200000 - jml_a
print("maka kembalian amad adalah : " + str(kem_a))
print()
print()
print("=====beni=======")
db = 3
eb = 1
mb = 2
j2 = 4
jml_b = (0.70 * ((db * dimsum) + (eb * es_krim) + (mb * milkshake))) + (j2 * 1800) - 5000
kem_b = 150000 - jml_b
print("jumlah belanjaan Beni : " + str(jml_b))
print("kembalian Beni adalah : " + str(kem_b))
print()
print("======Citra======")
ec = 3
j3 = 8
jml_c = (ec * es_krim) + (j3 * 2000) - 5000
kem_c = 60000 - jml_c
print("jumlah belanjaan Citra : " + str(jml_c))
print("kembalian citra adalah : " + str(kem_c))
print()
print("=======dadang======")
bd = 2
dd = 1
j4 = 5
jml_d = (0.80
         * ((bd * burger) + (dd * dimsum))) + (j4 * 1800) - 5000
kem_d = 100000 - jml_d
print("jumlah belanjaan dadang : " + str(jml_d))
print("kembalian dadang adalah : " + str(kem_d))
print("=======epen========")
ee = 4
e2 = 1
pe = 1
j5 = 12
jml_e = (0.70 * ((ee * ekkado) + (e2 * es_krim) + (pe * pizza))) + (j5 * 2200) - 5000
kem_e = 100000 - jml_e
print("maka jumlah epen adlah : " + str(jml_e))
print("maka kembalian epen adalah : " + str(kem_e))
print("=========soal 4========")
ba1 = 4
pa1 = 2
hsl = (0.30 * ((ba1 * 24000) + (pa1 * 52000))) + 5000
print("maka jumlah potongan ahmad adalah : " + str(hsl) )
db1 = 3
eb1 = 1
mb1 = 2
hsl1 = (0.30 *((db1 * 30000) + (eb1 * 15000) + (mb1 * 10000))) + 5000
print("maka jumlah potongan beni adalah : " + str(hsl1)) 
ec1 = 3
hsl2 = (0 * ((ec1 * es_krim))) + 5000
print("maka jumlah potongan citra adalah : " + str(hsl2))
bd1 = 2
dd1 = 1
hsl3 = (0.20 * ((bd1 * burger) + (dd1 * dimsum)))+ 5000
print("maka jumlah potongan dadang adalah : " + str(hsl3))
ee1 = 4
ese1 = 1
pe1 = 1
hsl4 = (0.30 * ((ee1 * 7500) + (ese1 * 15000) + (pe1 * 52000)))+5000
print("maka jumlah potongan epen adalah : " + str(hsl4))

print("=========soal 5========")
jarak = (7.5 * 2000) + (4 * 1800) + (8 * 2000) + (5 * 1800) + (12 * 2200)
print("maka jumlah semua setiap jarak dan ongkir adalah : " + str(jarak))
# Out:
# ======soal 1========
# maka jumlah semua makanan yang dipesan adalah : 545000
# jumlah semua belanjaan : 24
#
# ======soal 2=======
# Burger : 0.25
# Pizza : 0.125
# Dimsum : 0.16666666666666666
# Ekkado : 0.16666666666666666
# Milkshake : 0.08333333333333333
# Eskrim : 0.20833333333333334
# =====Soal 3=====
# =====Ahmad=====
# maka jumlah belanja amad : 150000.0
# maka kembalian amad adalah : 50000.0
#
#
# =====beni=======
# jumlah belanjaan Beni : 89700.0
# kembalian Beni adalah : 60300.0
#
# ======Citra======
# jumlah belanjaan Citra : 56000
# kembalian citra adalah : 4000
#
# =======dadang======
# jumlah belanjaan dadang : 66400.0
# kembalian dadang adalah : 33600.0
# =======epen========
# maka jumlah epen adlah : 89300.0
# maka kembalian epen adalah : 10700.0
# =========soal 4========
# maka jumlah potongan ahmad adalah : 65000.0
# maka jumlah potongan beni adalah : 42500.0
# maka jumlah potongan citra adalah : 5000
# maka jumlah potongan dadang adalah : 20600.0
# ...
